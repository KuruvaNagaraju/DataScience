# %% [markdown]
# # <center>**Pandas Introduction**</center>
# ---
#
# <br>

# %% [markdown]
# ## **Pandas DataFrame**

# %% [markdown]
# Pandas is an open-source Python Library providing high-performance data manipulation and analysis tool using its powerful data structures.
# The name Pandas is derived from the word Panel Data – an Econometrics from Multidimensional data.

# %% [markdown]
# ### Create an Empty DataFrame

# %%
## Import pandas library and create a empty dataframe.
import pandas as pd
df = pd.DataFrame()
print (df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Create a dataframe with a list as input

# %%
## Create a list with integers and display it.
l1=[1,2,3,4,5]
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
## Create a dataframe with list and display it.
datalist = pd.DataFrame(l1)
datalist
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %% [markdown]
# ### Create a dataframe with a list as input

# %%
## Create a list which contains list of lists.
stduentData = [['Alex',10],['Bob',12],['Clark',13]]
stduentData
# Out:
# [['Alex', 10], ['Bob', 12], ['Clark', 13]]

# %%
## Create a dataframe with list and assign column names as Names,Age and display it.
sdata=pd.DataFrame(stduentData,columns=['Names','Age'])
sdata
# Out:
#    Names  Age
# 0   Alex   10
# 1    Bob   12
# 2  Clark   13

# %%
## Create a dataframe with two lists.
student=pd.DataFrame([10,12,13],['Alex','Bob','Clark'])
student
# Out:
#         0
# Alex   10
# Bob    12
# Clark  13

# %%
## Create a dataframe with two lists.
student=pd.DataFrame(['Alex','Bob','Clark'],[10,12,13])
student
# Out:
#         0
# 10   Alex
# 12    Bob
# 13  Clark

# %% [markdown]
# ### Create a dataframe with a dictionary as input

# %%
## Initialize data frame.
dic={"Name":["Alex","Bob","Rachel"],"Age":[10,12,13]}

## Create a dataframe with dictionary and display it.
dicdata=pd.DataFrame(dic)
dicdata
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Rachel   13

# %% [markdown]
# ### Set Working Directory

# %%
## Import os library to connect machine.
import os

# %%
## Get current working directory.
os.getcwd()
# Out:
# 'D:\\Python\\Learning'

# %%
## Set working directory.
os.chdir('D:\DataScience\Pratice\Learning\Pandas Introduction')
os.getcwd()
# Out:
# 'D:\\DataScience\\Pratice\\Learning\\Pandas Introduction'

# %% [markdown]
# ### Reading data from CSV file

# %%
## Read ipl matches data from csv file.
ipl = pd.read_csv('matches2008-2016.csv')
ipl_new = pd.read_csv('matches2017.csv')

# %%
## Get dimensions of ipl data.
ipl.shape
# Out:
# (577, 19)

# %%
## Check first 5 records of ipl data.
ipl.head()
# Out:
#   match_id  season        city        date team1_id team2_id toss_winner  \
# 0   2008_1    2008   Bangalore  18-04-2008      KKR      RCB         RCB
# 1   2008_2    2008  Chandigarh  19-04-2008      CSK      KXI         CSK
# 2   2008_3    2008       Delhi  19-04-2008       RR       DD          RR
# 3   2008_4    2008      Mumbai  20-04-2008       MI      RCB          MI
# 4   2008_5    2008     Kolkata  20-04-2008       DC      KKR          DC
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal           0    KKR          140               0
# 1           bat  normal           0    CSK           33               0
# 2           bat  normal           0     DD            0               9
# 3           bat  normal           0    RCB            0               5
# 4           bat  normal           0    KKR            0               5
#
#     player_of_match  player_of_match_id  \
# 0  Brendon McCullum                82.0
# ...

# %%
## Check last 5 records of ipl data.
ipl.tail()
# Out:
#     match_id  season       city        date team1_id team2_id toss_winner  \
# 572  2016_56    2016     Raipur  22-05-2016       DD      RCB         RCB
# 573  2016_57    2016  Bangalore  24-05-2016       GL      RCB         RCB
# 574  2016_58    2016      Delhi  25-05-2016      SRH      KKR         KKR
# 575  2016_59    2016      Delhi  27-05-2016       GL      SRH         SRH
# 576  2016_60    2016  Bangalore  29-05-2016      SRH      RCB         SRH
#
#     toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 572         field  normal           0    RCB            0               6
# 573         field  normal           0    RCB            0               4
# 574         field  normal           0    SRH           22               0
# 575         field  normal           0    SRH            0               4
# 576           bat  normal           0    SRH            8               0
#
#       player_of_match  player_of_match_id  \
# ...

# %%
## Get summary statistics of ipl data.
ipl.describe(include='all')
# Out:
#        match_id       season    city        date team1_id team2_id  \
# count       577   577.000000     570         577      577      577
# unique      577          NaN      30         407       13       13
# top     2012_47          NaN  Mumbai  11-04-2010      CSK      RCB
# freq          1          NaN      77           2       77       77
# mean        NaN  2012.029463     NaN         NaN      NaN      NaN
# std         NaN     2.486247     NaN         NaN      NaN      NaN
# min         NaN  2008.000000     NaN         NaN      NaN      NaN
# 25%         NaN  2010.000000     NaN         NaN      NaN      NaN
# 50%         NaN  2012.000000     NaN         NaN      NaN      NaN
# 75%         NaN  2014.000000     NaN         NaN      NaN      NaN
# max         NaN  2016.000000     NaN         NaN      NaN      NaN
#
#        toss_winner toss_decision  result  dl_applied winner  win_by_runs  \
# count          577           577     577  577.000000    574   577.000000
# ...

# %%
## Get column names of ipl data.
ipl.columns
# Out:
# Index(['match_id', 'season', 'city', 'date', 'team1_id', 'team2_id',
#        'toss_winner', 'toss_decision', 'result', 'dl_applied', 'winner',
#        'win_by_runs', 'win_by_wickets', 'player_of_match',
#        'player_of_match_id', 'venue', 'venue_id', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
## Get column data types of ipl data.
ipl.dtypes
# Out:
# match_id               object
# season                  int64
# city                   object
# date                   object
# team1_id               object
# team2_id               object
# toss_winner            object
# toss_decision          object
# result                 object
# dl_applied              int64
# winner                 object
# win_by_runs             int64
# win_by_wickets          int64
# player_of_match        object
# player_of_match_id    float64
# venue                  object
# venue_id                int64
# umpire1                object
# umpire2                object
# dtype: object

# %%
## Get index range for ipl data.
ipl.index
# Out:
# RangeIndex(start=0, stop=577, step=1)

# %%
## Check null values of ipl data.
ipl.isna().sum()
# Out:
# match_id              0
# season                0
# city                  7
# date                  0
# team1_id              0
# team2_id              0
# toss_winner           0
# toss_decision         0
# result                0
# dl_applied            0
# winner                3
# win_by_runs           0
# win_by_wickets        0
# player_of_match       3
# player_of_match_id    3
# venue                 0
# venue_id              0
# umpire1               0
# umpire2               0
# dtype: int64

# %%
## Check dimensions of ipl_new data.
ipl_new.shape
# Out:
# (59, 19)

# %%
## Get first 5 records of ipl_new data.
ipl_new.head()
# Out:
#   match_id  season       city        date team1_id team2_id toss_winner  \
# 0   2017_1    2017  Hyderabad  05-04-2017      SRH      RCB         RCB
# 1   2017_2    2017       Pune  06-04-2017       MI      RPS         RPS
# 2   2017_3    2017     Rajkot  07-04-2017       GL      KKR         KKR
# 3   2017_4    2017     Indore  08-04-2017      RPS      KXI         KXI
# 4   2017_5    2017  Bangalore  08-04-2017      RCB       DD         RCB
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal           0    SRH           35               0
# 1         field  normal           0    RPS            0               7
# 2         field  normal           0    KKR            0              10
# 3         field  normal           0    KXI            0               6
# 4           bat  normal           0    RCB           15               0
#
#   player_of_match  player_of_match_id  \
# 0    Yuvraj Singh                  88
# ...

# %%
## Get last 5 records of ipl_new data.
ipl_new.tail()
# Out:
#    match_id  season       city        date team1_id team2_id toss_winner  \
# 54  2017_55    2017      Delhi  14-05-2017      RCB       DD         RCB
# 55  2017_56    2017     Mumbai  16-05-2017      RPS       MI          MI
# 56  2017_57    2017  Bangalore  17-05-2017      SRH      KKR         KKR
# 57  2017_58    2017  Bangalore  19-05-2017      KKR       MI          MI
# 58  2017_59    2017  Hyderabad  21-05-2017       MI      RPS          MI
#
#    toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 54           bat  normal           0    RCB           10               0
# 55         field  normal           0    RPS           20               0
# 56         field  normal           1    KKR            0               7
# 57         field  normal           0     MI            0               6
# 58           bat  normal           0     MI            1               0
#
#         player_of_match  player_of_match_id  \
# ...

# %%
## Check summary statistics of ipl_new data.
ipl_new.describe(include='all')
# Out:
#        match_id  season       city        date team1_id team2_id toss_winner  \
# count        59    59.0         59          59       59       59          59
# unique       59     NaN         10          43        8        8           8
# top     2017_55     NaN  Hyderabad  15-04-2017      SRH       MI          MI
# freq          1     NaN          8           2        9       11          11
# mean        NaN  2017.0        NaN         NaN      NaN      NaN         NaN
# std         NaN     0.0        NaN         NaN      NaN      NaN         NaN
# min         NaN  2017.0        NaN         NaN      NaN      NaN         NaN
# 25%         NaN  2017.0        NaN         NaN      NaN      NaN         NaN
# 50%         NaN  2017.0        NaN         NaN      NaN      NaN         NaN
# 75%         NaN  2017.0        NaN         NaN      NaN      NaN         NaN
# max         NaN  2017.0        NaN         NaN      NaN      NaN         NaN
#
# ...

# %%
## Get column names for ipl_new.
ipl_new.columns
# Out:
# Index(['match_id', 'season', 'city', 'date', 'team1_id', 'team2_id',
#        'toss_winner', 'toss_decision', 'result', 'dl_applied', 'winner',
#        'win_by_runs', 'win_by_wickets', 'player_of_match',
#        'player_of_match_id', 'venue', 'venue_id', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
## Get column data types of ipl_new data.
ipl_new.dtypes
# Out:
# match_id              object
# season                 int64
# city                  object
# date                  object
# team1_id              object
# team2_id              object
# toss_winner           object
# toss_decision         object
# result                object
# dl_applied             int64
# winner                object
# win_by_runs            int64
# win_by_wickets         int64
# player_of_match       object
# player_of_match_id     int64
# venue                 object
# venue_id               int64
# umpire1               object
# umpire2               object
# dtype: object

# %%
## Get index range for ipl_new data.
ipl_new.index
# Out:
# RangeIndex(start=0, stop=59, step=1)

# %%
## Check NA vallues for ipl_new data.
ipl_new.isna().sum()
# Out:
# match_id              0
# season                0
# city                  0
# date                  0
# team1_id              0
# team2_id              0
# toss_winner           0
# toss_decision         0
# result                0
# dl_applied            0
# winner                0
# win_by_runs           0
# win_by_wickets        0
# player_of_match       0
# player_of_match_id    0
# venue                 0
# venue_id              0
# umpire1               1
# umpire2               1
# dtype: int64

# %% [markdown]
# ## **Appending DataFrame**

# %%
ipl_final = ipl.copy()              ## Explicitly creating a copy of ipl. Just to make sure you don't modify your original data.
ipl_final = ipl_final.append(ipl_new) ## Append ipl_new with ipl_final.
print(ipl_final.shape) ## Display diemsnions of result dataframe.
# Out:
# (636, 19)

# %% [markdown]
# ## **Data Inspection**

# %%
## .shape gives dimentions of Data
                         # dim() in R - Dimentions of data.

# %%
print(ipl_final.shape) ## Get dimensions of ipl_final data.
# Out:
# (636, 19)

# %%
## Get first 3 records of ipl_final data.
ipl_final.head(3)
# Out:
#   match_id  season        city        date team1_id team2_id toss_winner  \
# 0   2008_1    2008   Bangalore  18-04-2008      KKR      RCB         RCB
# 1   2008_2    2008  Chandigarh  19-04-2008      CSK      KXI         CSK
# 2   2008_3    2008       Delhi  19-04-2008       RR       DD          RR
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal           0    KKR          140               0
# 1           bat  normal           0    CSK           33               0
# 2           bat  normal           0     DD            0               9
#
#     player_of_match  player_of_match_id  \
# 0  Brendon McCullum                82.0
# 1    Michael Hussey                18.0
# 2  Farveez Maharoof                60.0
#
#                                                venue  venue_id    umpire1  \
# 0         M.Chinnaswamy Stadium Bengaluru, Karnataka         7  Asad Rauf
# ...

# %%
## Get last 3 records of ipl_final data.
ipl_final.tail()
# Out:
#    match_id  season       city        date team1_id team2_id toss_winner  \
# 54  2017_55    2017      Delhi  14-05-2017      RCB       DD         RCB
# 55  2017_56    2017     Mumbai  16-05-2017      RPS       MI          MI
# 56  2017_57    2017  Bangalore  17-05-2017      SRH      KKR         KKR
# 57  2017_58    2017  Bangalore  19-05-2017      KKR       MI          MI
# 58  2017_59    2017  Hyderabad  21-05-2017       MI      RPS          MI
#
#    toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 54           bat  normal           0    RCB           10               0
# 55         field  normal           0    RPS           20               0
# 56         field  normal           1    KKR            0               7
# 57         field  normal           0     MI            0               6
# 58           bat  normal           0     MI            1               0
#
#         player_of_match  player_of_match_id  \
# ...

# %%
## .columns gives column names in python
## colnames() gives column names in R

# %%
ipl_final.columns
# Out:
# Index(['match_id', 'season', 'city', 'date', 'team1_id', 'team2_id',
#        'toss_winner', 'toss_decision', 'result', 'dl_applied', 'winner',
#        'win_by_runs', 'win_by_wickets', 'player_of_match',
#        'player_of_match_id', 'venue', 'venue_id', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
## .dtypes gives data types for each column in python
## str() in R - Data types.

# %%
ipl_final.dtypes
# Out:
# match_id               object
# season                  int64
# city                   object
# date                   object
# team1_id               object
# team2_id               object
# toss_winner            object
# toss_decision          object
# result                 object
# dl_applied              int64
# winner                 object
# win_by_runs             int64
# win_by_wickets          int64
# player_of_match        object
# player_of_match_id    float64
# venue                  object
# venue_id                int64
# umpire1                object
# umpire2                object
# dtype: object

# %% [markdown]
# <br><br>
# ## **Setting match_id as row index** (rarely used)

# %%
## set_index() is used to set an index.

# %%
## Get first record of ipl_final data.
ipl_final.head(1)
# Out:
#   match_id  season       city        date team1_id team2_id toss_winner  \
# 0   2008_1    2008  Bangalore  18-04-2008      KKR      RCB         RCB
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal           0    KKR          140               0
#
#     player_of_match  player_of_match_id  \
# 0  Brendon McCullum                82.0
#
#                                         venue  venue_id    umpire1  \
# 0  M.Chinnaswamy Stadium Bengaluru, Karnataka         7  Asad Rauf
#
#        umpire2
# 0  RE Koertzen

# %%
## Set match_id as index to ipl_final.
ipl_final = ipl_final.set_index(['match_id'])

# %%
## Get first record of ipl_new after setting index.
ipl_final.head(1)
# Out:
#           season       city        date team1_id team2_id toss_winner  \
# match_id
# 2008_1      2008  Bangalore  18-04-2008      KKR      RCB         RCB
#
#          toss_decision  result  dl_applied winner  win_by_runs  \
# match_id
# 2008_1           field  normal           0    KKR          140
#
#           win_by_wickets   player_of_match  player_of_match_id  \
# match_id
# 2008_1                 0  Brendon McCullum                82.0
#
#                                                venue  venue_id    umpire1  \
# match_id
# 2008_1    M.Chinnaswamy Stadium Bengaluru, Karnataka         7  Asad Rauf
#
#               umpire2
# match_id
# 2008_1    RE Koertzen

# %% [markdown]
# ## **Summary statistics**

# %%
## describe() method will give summary statistics of data.

# %%
ipl_final.describe(include='all') ## include='all' --> will include category types too.
# Out:
#              season    city        date team1_id team2_id toss_winner  \
# count    636.000000     629         636      636      636         636
# unique          NaN      30         450       13       13          13
# top             NaN  Mumbai  22-05-2014       MI       DD          MI
# freq            NaN      85           2       82       84          85
# mean    2012.490566     NaN         NaN      NaN      NaN         NaN
# std        2.773026     NaN         NaN      NaN      NaN         NaN
# min     2008.000000     NaN         NaN      NaN      NaN         NaN
# 25%     2010.000000     NaN         NaN      NaN      NaN         NaN
# 50%     2012.000000     NaN         NaN      NaN      NaN         NaN
# 75%     2015.000000     NaN         NaN      NaN      NaN         NaN
# max     2017.000000     NaN         NaN      NaN      NaN         NaN
#
#        toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# ...

# %% [markdown]
# ## **Dropping columns**

# %%
## Dropping Column
## using drop() method we frop a column/row.if the Axis = 1 then we are dropping a column and if axis is 0 then dropping a row.

## Drop city column and display first record of result(Here i didn't store result in same dataframe,so city will not drop from ipl_final).
ipl_final.drop('city',axis=1).head(1)
# Out:
#           season        date team1_id team2_id toss_winner toss_decision  \
# match_id
# 2008_1      2008  18-04-2008      KKR      RCB         RCB         field
#
#           result  dl_applied winner  win_by_runs  win_by_wickets  \
# match_id
# 2008_1    normal           0    KKR          140               0
#
#            player_of_match  player_of_match_id  \
# match_id
# 2008_1    Brendon McCullum                82.0
#
#                                                venue  venue_id    umpire1  \
# match_id
# 2008_1    M.Chinnaswamy Stadium Bengaluru, Karnataka         7  Asad Rauf
#
#               umpire2
# match_id
# 2008_1    RE Koertzen

# %% [markdown]
# ## **Dropping row**

# %%
## Drop a first record from ipl_final and display first record.
ipl_final.drop('2008_1',axis=0).head(1)  ## axis = 0 for rows.
# Out:
#           season        city        date team1_id team2_id toss_winner  \
# match_id
# 2008_2      2008  Chandigarh  19-04-2008      CSK      KXI         CSK
#
#          toss_decision  result  dl_applied winner  win_by_runs  \
# match_id
# 2008_2             bat  normal           0    CSK           33
#
#           win_by_wickets player_of_match  player_of_match_id  \
# match_id
# 2008_2                 0  Michael Hussey                18.0
#
#                                                       venue  venue_id  \
# match_id
# 2008_2    I.S. Bindra Punjab Cricket Association Stadium...         9
#
#             umpire1     umpire2
# match_id
# 2008_2    MR Benson  SL Shastri

# %% [markdown]
# ## **Frequency distribution**

# %%
## value_counts() gives frequency count in python
## table() in R - Frequency count.

ipl_final["winner"].value_counts()
# Out:
# MI     92
# CSK    79
# KKR    77
# RCB    73
# KXI    70
# RR     63
# DD     62
# SRH    42
# DC     29
# RPS    15
# GL     13
# PW     12
# KTK     6
# Name: winner, dtype: int64

# %%
ipl_final["winner"].replace({'DC':'SRH'},inplace=True) ## it is replacing DS with SRH  in winner column and stores reslt in same data frame
ipl_final['winner'].value_counts() ## It will count number of same elements in winner columns.
## inplce = True --> It will store result in same dataframe,by default it's value is False.
# Out:
# MI     92
# CSK    79
# KKR    77
# RCB    73
# SRH    71
# KXI    70
# RR     63
# DD     62
# RPS    15
# GL     13
# PW     12
# KTK     6
# Name: winner, dtype: int64

# %% [markdown]
# ## **loc (to subset data by Row/Column labels)**

# %%
## Label based indexing make more sense for column subsetting.
## Get first 3 records of ipl_final data and store in a varible and display it.
subset1 =ipl_final.head(3)
subset1
# Out:
#   match_id  season        city        date team1_id team2_id toss_winner  \
# 0   2008_1    2008   Bangalore  18-04-2008      KKR      RCB         RCB
# 1   2008_2    2008  Chandigarh  19-04-2008      CSK      KXI         CSK
# 2   2008_3    2008       Delhi  19-04-2008       RR       DD          RR
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal           0    KKR          140               0
# 1           bat  normal           0    CSK           33               0
# 2           bat  normal           0     DD            0               9
#
#     player_of_match  player_of_match_id  \
# 0  Brendon McCullum                82.0
# 1    Michael Hussey                18.0
# 2  Farveez Maharoof                60.0
#
#                                                venue  venue_id    umpire1  \
# 0         M.Chinnaswamy Stadium Bengaluru, Karnataka         7  Asad Rauf
# ...

# %%
subset1=ipl_final.loc[:,['venue','winner']] ## It will return all rows and venue,winnner columns
subset1.head() ## it will return first records
# Out:
#                                                       venue winner
# match_id
# 2008_1           M.Chinnaswamy Stadium Bengaluru, Karnataka    KKR
# 2008_2    I.S. Bindra Punjab Cricket Association Stadium...    CSK
# 2008_3                      Feroz Shah Kotla Stadium, Delhi     DD
# 2008_4                Wankhede Stadium, Mumbai, Maharashtra    RCB
# 2008_5            Eden Garden Stadium, Kolkata, West Bengal    KKR

# %%
## For loc based subsetting using row and column indexer together is rare.
subset2 =ipl_new.head(3)
subset2
# Out:
#   match_id  season       city        date team1_id team2_id toss_winner  \
# 0   2017_1    2017  Hyderabad  05-04-2017      SRH      RCB         RCB
# 1   2017_2    2017       Pune  06-04-2017       MI      RPS         RPS
# 2   2017_3    2017     Rajkot  07-04-2017       GL      KKR         KKR
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal           0    SRH           35               0
# 1         field  normal           0    RPS            0               7
# 2         field  normal           0    KKR            0              10
#
#   player_of_match  player_of_match_id  \
# 0    Yuvraj Singh                  88
# 1    Steven Smith                 321
# 2      Chris Lynn                 343
#
#                                            venue  venue_id         umpire1  \
# 0  Rajiv Gandhi International Stadium, Hyderabad         4     AY Dandekar
# ...

# %%
subset2=ipl_final.loc[['2009_1','2010_1','2011_1'],['venue','winner']] ## it will returrn 2009_1,2010_1,2011_1 rows and venue,winner columns data
subset2.head() ## It will return first 5 records by default but here we are mentioning 3 rows
# Out:
#                                                 venue winner
# match_id
# 2009_1                                       Newlands     MI
# 2010_1                     Dr DY Patil Sports Academy    KKR
# 2011_1    M.A.Chidambaram Stadium Chennai, Tamil Nadu    CSK

# %% [markdown]
# ## **iloc    (to subset data based on Row/Column number)**

# %%
## Numeric based indexing usually makes sense for row subsetting

# %%
subset3=ipl_final.iloc[5:10,:] ## It will return 5,6,--9 rows and all columns data.
subset3.head() ## It will return 5 records from subset.
# Out:
#           season        city        date team1_id team2_id toss_winner  \
# match_id
# 2008_6      2008      Jaipur  21-04-2008      KXI       RR         KXI
# 2008_7      2008   Hyderabad  22-04-2008       DC       DD          DC
# 2008_8      2008     Chennai  23-04-2008      CSK       MI          MI
# 2008_9      2008   Hyderabad  24-04-2008       DC       RR          RR
# 2008_10     2008  Chandigarh  25-04-2008      KXI       MI          MI
#
#          toss_decision  result  dl_applied winner  win_by_runs  \
# match_id
# 2008_6             bat  normal           0     RR            0
# 2008_7             bat  normal           0     DD            0
# 2008_8           field  normal           0    CSK            6
# 2008_9           field  normal           0     RR            0
# 2008_10          field  normal           0    KXI           66
#
#           win_by_wickets   player_of_match  player_of_match_id  \
# match_id
# ...

# %%
subset4 = ipl_final.iloc[70:91,3:7] ## It will return 70-90 rows and 3-6 columns data.
subset4.head() ## It will return first 5 records.
# Out:
#          team1_id team2_id toss_winner toss_decision
# match_id
# 2009_13       KXI       RR         KXI           bat
# 2009_14       CSK       DC          DC         field
# 2009_15        MI      KKR          MI           bat
# 2009_16        DD       RR          DD           bat
# 2009_17       KKR      RCB         KKR           bat

# %% [markdown]
# ## **Boolean indexing (to subset based on value in each cell of the column )**
# **Here we subsetting the data where the cell value in "City" column is equal to "Hyderabad"**

# %%
subset5 = ipl_final.loc[ipl_final['city']=='Hyderabad',:] ## it will return the records which city is equal to Hyderabad.
subset5.head(3)
# Out:
#           season       city        date team1_id team2_id toss_winner  \
# match_id
# 2008_7      2008  Hyderabad  22-04-2008       DC       DD          DC
# 2008_9      2008  Hyderabad  24-04-2008       DC       RR          RR
# 2008_18     2008  Hyderabad  01-05-2008       DC      KXI         KXI
#
#          toss_decision  result  dl_applied winner  win_by_runs  \
# match_id
# 2008_7             bat  normal           0     DD            0
# 2008_9           field  normal           0     RR            0
# 2008_18          field  normal           0    KXI            0
#
#           win_by_wickets  player_of_match  player_of_match_id  \
# match_id
# 2008_7                 9  Virender Sehwag                46.0
# 2008_9                 3     Yusuf Pathan               171.0
# 2008_18                7      Shaun Marsh               106.0
#
#                                                   venue  venue_id  \
# match_id
# ...
